# %%
logs_path = '/Users/artem.semidetnov/Desktop/MetaGenerator_v1/.cadence/cache/id2f7519f525f7457f899938c06c46d14c/45756/encodertrain.txt'

# %%
cntr = 0
with open(logs_path, 'r') as f:
    for line in f:
        if line.__contains__('Validation'):
            print(line)
        # if not line.__contains__('Epoch') and not line.__contains__('INFO'):
        #     cntr += 1
        #     print(line)
        if cntr < 1000:
            continue
        if cntr >= 10000:
            break
# Out:
# [2025-12-19 11:06:38,524]   INFO - Validation: |          | 0/? [00:00<?, ?it/s]
#
# [2025-12-19 11:06:38,525]   INFO - Validation: |          | 0/? [00:00<?, ?it/s]
#
# [2025-12-19 11:06:38,573]   INFO - Validation DataLoader 0:   0%|          | 0/16 [00:00<?, ?it/s]
#
# [2025-12-19 11:06:38,873]   INFO - Validation DataLoader 0:   6%|▋         | 1/16 [00:00<00:04,  3.27it/s]
#
# [2025-12-19 11:06:45,475]   INFO - Validation DataLoader 0:  12%|█▎        | 2/16 [00:06<00:47,  0.29it/s]
#
# [2025-12-19 11:06:52,077]   INFO - Validation DataLoader 0:  19%|█▉        | 3/16 [00:13<00:57,  0.23it/s]
#
# [2025-12-19 11:06:58,379]   INFO - Validation DataLoader 0:  25%|██▌       | 4/16 [00:19<00:59,  0.20it/s]
#
# [2025-12-19 11:07:04,981]   INFO - Validation DataLoader 0:  31%|███▏      | 5/16 [00:26<00:57,  0.19it/s]
#
# [2025-12-19 11:07:11,583]   INFO - Validation DataLoader 0:  38%|███▊      | 6/16 [00:32<00:54,  0.18it/s]
#
# ...
